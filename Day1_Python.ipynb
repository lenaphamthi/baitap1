# %% [markdown]
# <a href="https://colab.research.google.com/github/lenaphamthi/baitap1/blob/master/Day1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input()) 
if n%2 == 1 :
  print("weird") 
if n%2 == 0 and n >= 2 and n <=5 :
  print("not weird")
if n%2 == 0 and n >=6 and n >= 20 :
  print("weird")
if n%2 == 0 and n > 20 :
  print("not weird")
# Out:
# 4
# not weird

# %%
set1 = set()
for i in range(5):
  set1.add(i)
set2 = {3, 4, 5, 6, 7, 8}
# Intersection using intersection() function
set3 = set1.intersection(set2)
print("Intersection using intersection() function")
print(set3)
# Intersection using "&" operator
set3 = set1 & set2
print("\nIntersection using '&' operator")
print(set3)
# Out:
# Intersection using intersection() function
# {3, 4}
#
# Intersection using '&' operator
# {3, 4}

# %%
print("hi".upper())
# Out:
# HI

# %%
x = input ("nhap ten lop :")
if x == "AIDS" :
  print("chao mung")
else:
  print ("xin loi")
# Out:
# nhap ten lop :AIDS
# chao mung

# %%
def sayHello():
 print("Hello world")
sayHello()
# Out:
# Hello world

# %%
def sayHello_n_times(n):
 for i in range(n):
  print("Hello world")
sayHello_n_times(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0d05f2e6fd27> in <module>()
#       2  for i in range(n):
#       3   print("Hello world")
# ----> 4 sayHello_n_times(n)
#
# NameError: name 'n' is not defined

# %%
def gttd(n) : 
  if n >= 0 :
    return (n)
  else:
      return -n
m = int (input (" nhap 1 so : "))
print ("gia tri tuyet doi ", m , "la ", (gttd(m)))
# Out:
#  nhap 1 so : -100
# gia tri tuyet doi  -100 la  100

# %%
def getValue():
  a =15
  return a
getValue()
# Out:
# 15

# %%
def max (num1, num2):
  if num1 > num2  :
    return num1 
  else :
    return num2 
num1 = int(input("nhap num 1 : "))
num2 = int(input("nhap num 2 : "))
print (('so lon nhat la : ') , max(num1, num2))
# Out:
# nhap num 1 : 15
# nhap num 2 : 9
# so lon nhat la :  15

# %%
def nPrintln(message, n):
  for i in range(0, n):
    print(message)
nPrintln (n= 5, message = " welecome to python")
# Out:
#  welecome to python
#  welecome to python
#  welecome to python
#  welecome to python
#  welecome to python

# %%
n = "xin chao"
while (n) :
  print(n)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# xin chao
# ...

# %%
import math
x=float(input("x= "))
y=float(input("y= "))
#Tri tuyet doi
a=abs(x)
print("tri tuyet doi cua x la ", a)
#Lay phan nguyen cua so
a=int(x)
print("phan nguyen cua x la ",a)
#Chuyen doi thanh so thuc
a=float(x)
print("chuyen doi x thanh so thuc",a)
#Tinh luy thua x mu y
a=x**y
print("luy thua ", a)
#Tinh can bac hai
a=math.sqrt(abs(x))
print("can bac hai cua x la ",a)
# Out:
# x= -1.0
# y= 2.0
# tri tuyet doi cua x la  1.0
# phan nguyen cua x la  -1
# chuyen doi x thanh so thuc -1.0
# luy thua  1.0
# can bac hai cua x la  1.0
